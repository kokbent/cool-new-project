# %%
import sqlite3

# %%
db = sqlite3.connect("survey.db")

# %%
import pandas as pd

# %%
# Plot some reading vs date
df = pd.read_sql_query('''SELECT * FROM Survey JOIN Visited
                          ON Visited.id = Survey.taken''', db)
df
# Out:
#     taken person quant  reading   id   site       dated
# 0     619   dyer   rad     9.82  619   DR-1  1927-02-08
# 1     619   dyer   sal     0.13  619   DR-1  1927-02-08
# 2     622   dyer   rad     7.80  622   DR-1  1927-02-10
# 3     622   dyer   sal     0.09  622   DR-1  1927-02-10
# 4     734   lake   sal     0.05  734   DR-3  1930-01-07
# 5     734     pb   rad     8.41  734   DR-3  1930-01-07
# 6     734     pb  temp   -21.50  734   DR-3  1930-01-07
# 7     735   None   sal     0.06  735   DR-3  1930-01-12
# 8     735   None  temp   -26.00  735   DR-3  1930-01-12
# 9     735     pb   rad     7.22  735   DR-3  1930-01-12
# 10    751   lake   sal     0.10  751   DR-3  1930-02-26
# 11    751     pb   rad     4.35  751   DR-3  1930-02-26
# 12    751     pb  temp   -18.50  751   DR-3  1930-02-26
# 13    752   lake   rad     2.19  752   DR-3        None
# 14    752   lake   sal     0.09  752   DR-3        None
# 15    752   lake  temp   -16.00  752   DR-3        None
# ...

# %%
df = pd.read_sql_query('''SELECT * FROM Survey JOIN Visited
                          ON Visited.id = Survey.taken
                          WHERE dated IS NOT NULL''', db)
df
# Out:
#     taken person quant  reading   id   site       dated
# 0     619   dyer   rad     9.82  619   DR-1  1927-02-08
# 1     619   dyer   sal     0.13  619   DR-1  1927-02-08
# 2     622   dyer   rad     7.80  622   DR-1  1927-02-10
# 3     622   dyer   sal     0.09  622   DR-1  1927-02-10
# 4     734   lake   sal     0.05  734   DR-3  1930-01-07
# 5     734     pb   rad     8.41  734   DR-3  1930-01-07
# 6     734     pb  temp   -21.50  734   DR-3  1930-01-07
# 7     735   None   sal     0.06  735   DR-3  1930-01-12
# 8     735   None  temp   -26.00  735   DR-3  1930-01-12
# 9     735     pb   rad     7.22  735   DR-3  1930-01-12
# 10    751   lake   sal     0.10  751   DR-3  1930-02-26
# 11    751     pb   rad     4.35  751   DR-3  1930-02-26
# 12    751     pb  temp   -18.50  751   DR-3  1930-02-26
# 13    837   lake   rad     1.46  837  MSK-4  1932-01-14
# 14    837   lake   sal     0.21  837  MSK-4  1932-01-14
# 15    837    roe   sal    22.50  837  MSK-4  1932-01-14
# ...

# %%
for i in range(0, 17):
    if (df.loc[i, 'quant'] == 'sal') & (df.loc[i, 'reading'] > 1):
        df.loc[i, 'reading'] = df.loc[i, 'reading'] / 100
        print("Readings is changed at row ", i)
# Out:
# Readings is changed at row  15

# %%
df
# Out:
#     taken person quant  reading   id   site       dated
# 0     619   dyer   rad    9.820  619   DR-1  1927-02-08
# 1     619   dyer   sal    0.130  619   DR-1  1927-02-08
# 2     622   dyer   rad    7.800  622   DR-1  1927-02-10
# 3     622   dyer   sal    0.090  622   DR-1  1927-02-10
# 4     734   lake   sal    0.050  734   DR-3  1930-01-07
# 5     734     pb   rad    8.410  734   DR-3  1930-01-07
# 6     734     pb  temp  -21.500  734   DR-3  1930-01-07
# 7     735   None   sal    0.060  735   DR-3  1930-01-12
# 8     735   None  temp  -26.000  735   DR-3  1930-01-12
# 9     735     pb   rad    7.220  735   DR-3  1930-01-12
# 10    751   lake   sal    0.100  751   DR-3  1930-02-26
# 11    751     pb   rad    4.350  751   DR-3  1930-02-26
# 12    751     pb  temp  -18.500  751   DR-3  1930-02-26
# 13    837   lake   rad    1.460  837  MSK-4  1932-01-14
# 14    837   lake   sal    0.210  837  MSK-4  1932-01-14
# 15    837    roe   sal    0.225  837  MSK-4  1932-01-14
# ...

# %%
saldf = df[df.quant == 'sal']
saldf
# Out:
#     taken person quant  reading   id   site       dated
# 1     619   dyer   sal    0.130  619   DR-1  1927-02-08
# 3     622   dyer   sal    0.090  622   DR-1  1927-02-10
# 4     734   lake   sal    0.050  734   DR-3  1930-01-07
# 7     735   None   sal    0.060  735   DR-3  1930-01-12
# 10    751   lake   sal    0.100  751   DR-3  1930-02-26
# 14    837   lake   sal    0.210  837  MSK-4  1932-01-14
# 15    837    roe   sal    0.225  837  MSK-4  1932-01-14

# %%
from datetime import datetime

X = saldf.dated
X = pd.to_datetime(X).astype(datetime)
X
# Out:
# 1     1927-02-08 00:00:00
# 3     1927-02-10 00:00:00
# 4     1930-01-07 00:00:00
# 7     1930-01-12 00:00:00
# 10    1930-02-26 00:00:00
# 14    1932-01-14 00:00:00
# 15    1932-01-14 00:00:00
# Name: dated, dtype: object

# %%
Y = saldf.loc[:, "reading"]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

plt.plot_date(X, Y)
